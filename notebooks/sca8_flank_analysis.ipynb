# %% [markdown]
# # SCA8 flank analysis

# %%
import gzip
from os import listdir
from os.path import isfile, join

input_path = '/opt/data/sca8_11/fastq/guppy/'
fastq_paths = sorted(join(input_path, f) for f in listdir(input_path) if 'fastq' in f and isfile(join(input_path, f)))

# %%
fastq_paths
# Out:
# ['/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_0.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_1.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_10.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_11.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_12.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_13.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_14.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_2.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_3.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_4.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_5.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_6.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_7.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_8.fastq.gz',
#  '/opt/data/sca8_11/fastq/guppy/ASF635_pass_barcode11_08b5eb5b_bf372731_9.fastq.gz']

# %%
COMPLEMENT = {
    'A': 'T',
    'C': 'G',
    'G': 'C',
    'T': 'A'
}

def rev_comp(seq, comps):
    return ''.join(comps.get(n, n) for n in reversed(seq))

# %%
def process_fastq(fastq_path):
    fastq_name = fastq_path.split('/')[-1]
    gzipped = fastq_name.endswith('.gz')
    openner = gzip.open if gzipped else open

    with openner(fastq_path, 'rt') as f:
        seqs = []
        for i, line in enumerate(f):
            line = line.strip()
            if i%4 == 0:
                if line.startswith('@'):
                    id = line.split(' ')[0]
                else:
                    print(f'Error in {fastq_path} line {i} - not an ID line')
                    raise
            elif i%4 == 1:
                seq = line
                seqs.append(seq)
            elif i%4 == 2:
                if line.startswith('+'):
                    opt = line
                else:
                    print(f'Error in {fastq_path} line {i} - not a + line')
                    raise
            elif i%4 == 3:
                qual = line
        return seqs

# %%
reads = [process_fastq(f) for f in fastq_paths]

# %%
len(reads)
# Out:
# 15

# %%
reads = sum(reads, [])

# %%
len(reads)
# Out:
# 43572

# %%
sum(1 for r in reads if 'TAGTAGTAG' in r)
# Out:
# 27287

# %%
fwd_prefixes = {}
rev_prefixes = {}
for r in reads:
    ix = r.find('CTACTACTA')
    if ix != -1:
        prefix = r[ix-25:ix]
        if prefix in fwd_prefixes:
            fwd_prefixes[prefix] += 1
        else:
            fwd_prefixes[prefix] = 1

    ix = r.find('CAGCAGCAG')
    if ix != -1:
        prefix = r[ix-25:ix]
        if prefix in rev_prefixes:
            rev_prefixes[prefix] += 1
        else:
            rev_prefixes[prefix] = 1

# %%
len(fwd_prefixes)
# Out:
# 2349

# %%
len(rev_prefixes)
# Out:
# 5506

# %%
rev_prefixes
# Out:
# {'TAAGATAATATATTTTTAAAAAATG': 8407,
#  'AAATAAGATAATATATTAAAAAATG': 1407,
#  'AATAAGATAATATCTTTAAAAAATG': 154,
#  'AATAAGATAATATATTTAAAAAATG': 2031,
#  'TGGATTAATATATTTTTAAAAAATG': 8,
#  'TAAGATGATGTATTTTTAAAAAATG': 35,
#  'ATAAGATAATATATTTTAAAAAATG': 3470,
#  'AAATAAGATGATCTGTTAAAAAATG': 140,
#  'ATAAGATAATATCCTTTAAAAAATG': 82,
#  'AAATAAGATAAATATCTAAAAAATG': 1,
#  'TAAATAAGATAATATCTAAAAAATG': 24,
#  'AAGATAATATATTTAGAAAAAAATG': 2,
#  'AAGATAATATATTTTTTAAAAAATG': 708,
#  'AAGATCATGTATTTTTTAAAAAATG': 2,
#  'TAAGATAATATACTTTTAAAAAATG': 157,
#  'AGATAATATATTTTAAAAAATGCGG': 15,
#  'GATAATCTTGACTTTTTAAAAAATG': 1,
#  'ATAAGATAATATATTTTTAAAAATG': 176,
#  'TATATTTTAAAAAATGCAACAGCGG': 1,
#  'GCTGCTGCTGCTGCTGCTGCTGCTG': 46,
#  'GATAATATATTTTTTCATTTGCGGA': 1,
#  'AGATGATATTATTTTTTAAAAAATG': 15,
#  'TGATGTGTTTGAAAAAATGCAGCGG': 1,
#  'AGATAATATATATTTTTAAAAAATG': 77,
#  'AATAAGATAATATGTACAAAAAATG': 1,
#  'ATAAGATAATATACCTTAAAAAATG': 5,
#  'TAAGATAATATATATTTAAAAAATG': 52,
#  'GAATAAGATGATCTGTTAAAAAATG': 4,
#  'CAAGATAATATATTTTTAAAAAATG': 36,
#  'AAGAATAATATATTTTTAAAAAATG': 87,
#  'TAAGATAATAAATTTTTAAAAAATG': 4,
#  'CCAACGGCAGGCGCGCAGGCGGGCG': 1,
#  'AAGATAAATAATGTGTTAAAAAATG': 1,
#  'ATACGATGGGATCTGCTAAAAAATG': 1,
#  'TTATATATTTTTAAAAATACGGGCA': 1,
#  'TAAGATAATATATTTTTAAGAAATG': 30,
#  'CAAGCTGATGTATTTTTAAAAAATG': 1,
#  'AAAATAAGATAATATCTAAAAAATG': 281,
#  'AATAAGATAATATATTTTAAAAATG': 76,
#  'AAAATAAGATAATATATTAAAAATG': 50,
#  'TAGGATAATATATTTTTAAAAAATG': 34,
#  'AATAAGATAATATCCTTAAAAAATG': 101,
#  'AATAAGATGATATTCTTAAAAAATG': 36,
#  'TGAGATAATATATTTTTAAAAAATG': 26,
#  'ATACAGTGATCTATTTTAAAAAATG': 1,
#  'AAGATGATGTATTTTTTAAAAAATG': 6,
#  'AAATAAGATAATATCTTAAAAAATG': 175,
#  'AAATAAGATGATCTATTAAAAAATG': 11,
#  'AATAAGATAATATCTCTAAAAAATG': 2,
#  'TAAGATAATATATTTATAAAAAATG': 6,
#  'ATAAGATAATATACTTTAAAAAATG': 165,
#  'ATAATATATTTAAAAAATGCAGCTG': 4,
#  'GATAATATATTTTTAAAAAAAGTAG': 4,
#  'AAATAAGATAATCTGTTAAAAAATG': 106,
#  'AAGATAATATATTTTTAAAAAAATG': 47,
#  'TAAGATAATATACATTTAAAAAATG': 9,
#  'AGATAATATACATTTTTAAAAAATG': 30,
#  'TACAATAATATATTTTCAAAAAATG': 1,
#  'AAATAAGATAATATATTTAAAATCC': 1,
#  'ATAAGATAATATATTTAGAAAAATG': 8,
#  'AGATAATATATTTTAAAAAATGCAA': 7,
#  'TAAATAAGATAATATATTAAAAATG': 8,
#  'AATATTTTAAAAAATGCAGCAGCGG': 1,
#  'AATAAGATAATATTGTTAAAAAATG': 30,
#  'TAAGATAATATATTTAGAAAAAATG': 14,
#  'GTAAAATAAGATAATATATTAAATC': 2,
#  'AATAAGATGATATTGTTAAAAAATG': 34,
#  'CAACAAGATAATATATTAAAAAATG': 1,
#  'AAGATGATCTATTTTTTAAAAAATG': 18,
#  'AAAATAAGATAATATAGTAAAAATG': 1,
#  'CAAGATGATGTCCTCTTAAAAAATG': 1,
#  'TAAGATAATGTATTTTTAAAAAATG': 34,
#  'ATGAAGTCATGCTGTTTAAAAAATG': 2,
#  'GCCAATGAGATTAATATATTAAACG': 1,
#  'ATAATATATTTTTAAAAAATATGAG': 1,
#  'AAATAAGATAATATCTAAAAAAATG': 12,
#  'AAATAAGATGATCTACTAAAAAATG': 1,
#  'AAAAATGCGGGCGCGCGCGCGCGCG': 1,
#  'TAGAATAATATATTTTTAAAAAATG': 20,
#  'ATAAGATGATACTCTTTAAAAAATG': 1,
#  'AAGATAATATAGTTTTTAAAAAATG': 11,
#  'TAAGATAATATATTTTTATAAAATG': 1,
#  'AATAAGATGATGTATTTTAAAAATG': 2,
#  'AAAATAAGATAATATATTAAAAATA': 2,
#  'AAAATAAGATAATATATAAAAAATG': 58,
#  'AAAATAAGATGATGTCTAAAAAATG': 35,
#  'ATAAATAATGTATTTTTAAAAAATG': 1,
#  'ATAATAATATATTTTTTAAAAAATG': 11,
#  'AAAATAAGATGACGTCTAAAAAATG': 1,
#  'GATAATATATTTTTAAAAAATGCGG': 29,
#  'AAATAAGATGATGTATAAAAAAATG': 1,
#  'AAAATAAGTACTTTTTTAAAAAATG': 1,
#  'AATAAGATAATATTTTTAAAAAATG': 26,
#  'CCTCCGATAGATGAAACCAGCACCT': 22,
#  'AAGATGATATTATTTTTAAAAAATG': 60,
#  'ATAAGATGATATTCTAAAAATGCGG': 1,
#  'AATAAGATAATATATTTAAGAAATG': 4,
#  'ATAAGATAATATATCTTAAAAGATG': 1,
#  'AGTAAAATAAGTGTTTGAAAAAATG': 1,
#  'GGCGCGCGCGCGCAGGCAGCAGGCG': 1,
#  'ATAAATAGGTGTAGGTTTAAAAATG': 1,
#  'AATAAGATGATCTGTTTAAAAAATG': 19,
#  'AAATAAGAAAATATATTAAAAAATG': 1,
#  '': 5,
#  'TAAGATAATATATCTTTAAAAAATG': 76,
#  'AAAATAAGATAATATTTAAAAAATG': 55,
#  'GATAAAAAATATATTTTAAAAAATG': 1,
#  'TAAGATAATATAATTTTAAAAAATG': 42,
#  'GCTGCTGCTGTTGCTGCTGCTGCTG': 2,
#  'AAATAATAATATATTTTAAAAAATG': 38,
#  'ATAGATGTATTTTTCAGAAAAAATC': 1,
#  'TAATATATTTTAAAAATGGGGCGAG': 1,
#  'ATATTTTTAAAAAATGCAGCAGTAG': 8,
#  'AGATGGGCATTTTTTTTAAAAAATG': 1,
#  'TAAGAATAATATATTTTAAAAAATG': 31,
#  'AGTAAAATAAGATAATATACTGATC': 1,
#  'AAATAAGAATATCTTTGAAAAAATG': 1,
#  'AAAATAAGATAATATATTTCAACTG': 1,
#  'GGATGAAACCAGCACCTGAAAAATG': 1,
#  'TAAGATAATATATTTTTAGAAAATG': 30,
#  'TAAGATAATATATTTCCAAAAAATG': 3,
#  'AATAAGATGATCTATTTGAAAACTG': 1,
#  'AATAGATAATATATTTTAAAAAATG': 11,
#  'ATAAGATGATGTACGCTAAAAAATG': 1,
#  'TAAAATAAGATAATATATTTGATTC': 3,
#  'AGATAATATCATTTTTTAAAAAATG': 3,
#  'GATGGTGGATGATGATGTTGAGATG': 1,
#  'AAAATAAGATAATATATTAAATTAG': 2,
#  'GTAAAATAAGATGATGTAAAAAATG': 1,
#  'TAAGATAATATATTTCTAAAAAATG': 46,
#  'AATGAGGTAATATATTTAAAAAATG': 1,
#  'AGATAATATCCTTTTTTAAAAAATG': 8,
#  'CGTATTGCTGCTGCTGCTGCTGCTG': 1,
#  'TGAAGTAATATATTCTTAAAAAATG': 1,
#  'GTAAAATGATAATATATAAAAAATG': 1,
#  'ATGTTTTTTAAGATGCAGCACTAGG': 1,
#  'ATAAGATGATATTGTTTAAAAAATG': 7,
#  'GGCGCGCGGCACAGCAGGCACGGCG': 1,
#  'AAGTCGATGATATCTTTAAAAAATG': 2,
#  'TATTTTTAAAAAATGCAGCACATAG': 1,
#  'AATATATTTTTAAAAAATGCAGCAT': 3,
#  'TAAGGTAATATATTTTTAAAAAATG': 37,
#  'ATAAAGTAATATCCTTTAAAAAATG': 2,
#  'ATAATATATTATTTTTTAAAAAATG': 4,
#  'ATAAGATAATATATTTCAAAAAATG': 29,
#  'AAAATAAGATAATATATTTCAATAG': 1,
#  'TATATTTTTAAAAAATGCAGCAGAG': 2,
#  'CGCGCGCGCGCGGCGCGCGCGCGCG': 1,
#  'AATAAGATAATATATTAAAAAAATG': 56,
#  'GATGATGCTGTTTTTTTAAAAAATG': 1,
#  'TTAGATAATATATTTTTAAAAAATG': 8,
#  'TAAAGTGATCTATTTTTAAAAAATG': 9,
#  'TAAAACAAGATAATATTAAAAAATG': 1,
#  'AATAATGATATTATTTCAAAAAATG': 1,
#  'TAAGATGATGTTGTTCCAAAAAATG': 1,
#  'GTACATTTAAAAAATGCAGCGGGGC': 1,
#  'GTTATATATTTTTAAAAAATGCAGG': 2,
#  'AATGAGATAATATATTTAAAAAATG': 5,
#  'AAGATAAATATATTTTTAAAAAATG': 11,
#  'AATAAGATAATATATTAAACACGAG': 1,
#  'AGTGAGTGTACACCTTTAAAAAATG': 1,
#  'ATAATATATTTATTTTTAAAAAATG': 4,
#  'AGATGGGTGTAGCTTGAAAAAAATG': 1,
#  'ATGAGATAATATATTTTAAAAAATG': 18,
#  'ATGATATTATTTTTAAAAAATGTAG': 1,
#  'AATAAGATGATGTTCTTAAAAAATG': 1,
#  'AAGATAGTATATTTTTTAAAAAATG': 6,
#  'AAATAAGATAATATTGTAAAAAATG': 4,
#  'AAAATAAGATAATATTTAAAGAATG': 1,
#  'TAAGATCATGTATTTTTAAAAAATG': 8,
#  'GATAGTATATTTTTTAAAAAGAATC': 1,
#  'AATAAGATGATGTAGCTTAAAAATG': 1,
#  'ATAAGATAATATATGTTTAAAAATG': 2,
#  'CTACTACTACTACTGTCTGCTGCTG': 1,
#  'ATAAGATGATATTATTTAAAAAATG': 37,
#  'AAATAAGACAATATATTTAAAAATG': 1,
#  'AAGATTAATATACTTTTAAAAAATG': 1,
#  'AAGATAATATATTTAAAAAATGCGG': 6,
#  'ATAAGATAATATACTTCAAAAAATG': 4,
#  'AAAAATAATATATTTTTAAAAAATG': 1,
#  'ATAAGATAATATCTTCTTTAAACTG': 1,
#  'TAAAATAAGATAATCTATTAAATTG': 1,
#  'AAGATGATATTATTTTTAAAGAATG': 1,
#  'TAAAAATAATAATATTTAAAAAATG': 1,
#  'ATAAGATAATATAGTTTAAAAAATG': 33,
#  'TAAGATAATATATTCTTAAAAAATG': 71,
#  'GAAGTGGATGGATGTCTAAAAAATG': 1,
#  'TAATATATTTTAAAAAATGCAGTAG': 5,
#  'TGAATCAAGATGATGTCTAAAAATG': 1,
#  'ATAAGATAATATATTTTAGAAAATG': 16,
#  'ATAAGATAATATATTTTAAAAAATA': 6,
#  'AGTAATGTAATCTATTAAAAAAATG': 1,
#  'TAAAATAAGATAATATATTAAAATG': 24,
#  'ATTGTTATATCTTTAAAAAATGTAG': 1,
#  'TCCGATAGATGAAACCAGCACCTAG': 10,
#  'AAGATAATATATTTTTGAAAAAATG': 35,
#  'TAAGATGATGTACATTTAAAAAATG': 1,
#  'GATAGATGAAACCAGCACCTAAATG': 2,
#  'AAATAAGATAATATCTGCGAAAATG': 1,
#  'AATGATAATATATTTTTAAAAAATG': 2,
#  'ATAAGATAATATATTTAAAAAAATG': 37,
#  'TAAGATAATATATTTTTTAAAAATG': 38,
#  'TAAAATAATAATATATTAAAAAATG': 6,
#  'AAATAAGATAATATCCTAAAAAATG': 64,
#  'AAATAAGATAATATTTTAAAAAATG': 26,
#  'GCGCGCGCGCGGCGCGGGCGCGGCG': 1,
#  'TAAGATGATATATTTTTAAAAAATG': 35,
#  'TGCAGCGGCGGGCGGCGCGCGAGCG': 1,
#  'AAATAAGATGATATCTTAAAAAATG': 3,
#  'AAATAAGATAATATGCTAAAAAATG': 10,
#  'AATAAGATAATATATTTAAAGAATG': 16,
#  'ATAAGATAATATATTTTAAAAAGTG': 10,
#  'ATAAGATAATATAGCTTAAAAAATG': 19,
#  'AATAAGATAATATAGTTTAAAAATG': 1,
#  'AATAAGATAATATACTTAAAAAATG': 60,
#  'GAAATAAGATAATATTTAAAAAATG': 1,
#  'AATAAGATAATATATTGAAGAAACG': 3,
#  'AAGATAATATACTTTTTAAAAAATG': 47,
#  'ATGAAACCAGCACCTAAAATACGAG': 1,
#  'AAATAAGATAATATATTTTTAAACG': 3,
#  'AGATAATATATTTTAAAATACGCGG': 1,
#  'TGTCTAAAAAATGCAGCAGCGGCGG': 1,
#  'GATAATATATTTTTAAAAAATGTAG': 11,
#  'ACAAGATAATATACTTTAAAAAATG': 1,
#  'TAAGATAATATATTAAAAATCCGAG': 1,
#  'ATATATTTAAAAAATGCAGCAGCGG': 8,
#  'ATAAAGTGATCTATTTTAAAAAATG': 2,
#  'TGAGACATATATATTTTAAAAAATG': 1,
#  'AAGATAATATATTTTTAAAAATCCA': 1,
#  'TAAATAAGATGATGTCTAAAAAATG': 14,
#  'AAGATAGTATCATTTTTAAAAAATG': 1,
#  'AATAAAGTGATATTATTAAAAAATG': 2,
#  'ATAAGATAATATAATTTAAAAAATG': 8,
#  'AGTAAAATAATATATTTAAAAAATG': 1,
#  'GTAAAATGAGTGGTTGCAAAAAATG': 1,
#  'TAAGATAATATATTTAAAAAAGTAG': 2,
#  'TAAAATAAGATAATCTTAAAAAATG': 10,
#  'TGATGTCTTAAAAATACAGCAGCGG': 1,
#  'TAAAATAAGATAATATATAAAAATG': 46,
#  'TAAGATGATCTATTTTTAAAAAATG': 63,
#  'AGATGATCTGTTGAAAAAATACAGC': 1,
#  'AAATAAGATAATATAGCTAAAAGTG': 2,
#  'AGGATTAATATATTTTTAAAAAATG': 2,
#  'AAAATAAGATAATATTAAAAAAATG': 2,
#  'AAATAAGATGATATTCTAAAAAATG': 23,
#  'CCGATAGATGAAACCAGCACCTATG': 4,
#  'AATATGATAATATATTTAAAAAATG': 3,
#  'AAATAAGATAATATATAAATACGAG': 1,
#  'TAATTGTTATATATTTTAAAAAATG': 1,
#  'AATAAGATAATATGTTTAAAAAATG': 20,
#  'GAAAAGGATGATACTTTTAAAAATG': 1,
#  'AATAAGATAATCTGTTCAAAAAATG': 3,
#  'ATAAGATAGTATATTTTAAAAAATG': 12,
#  'AGATGAAACCAGCACCTTAAAAATG': 1,
#  'ATATTTTTAAAAAATGCAGCAGCGA': 1,
#  'ATAAGATAATATCTGTTAAAAAATG': 11,
#  'ATAAAATAATATATTTTAAAAAATG': 21,
#  'GATAATATCCTTTAAAAAATCCGAG': 1,
#  'AAATAAGATAATATGTTCTTGAACG': 1,
#  'TAAGATAATATATGTTTAAAAAATG': 27,
#  'TAAGACAATATATTTTTAAAAAATG': 28,
#  'TAGATGATGATATTATTAAAAAATG': 1,
#  'ATAGAATAATATATTTTAAAAAATG': 13,
#  'GCTGCTGCTGCTACTGCTGCTGCTG': 1,
#  'AAATAAGATAATATATTAAAAATCC': 1,
#  'AATATATTTTTAAAAAATGCAGTAG': 12,
#  'TAAAATAAGATGATCTGTTAGAATG': 1,
#  'AAGAAGATAATATATTTAAAAAATG': 1,
#  'AAGATAATATATTTTTTAGAAAATG': 2,
#  'AAATAAGATGATGTATTAAAGAATG': 1,
#  'AATAAGATGATATCTTTAAAAAATG': 16,
#  'AAAGTAAGATAATATCTAAAAAATC': 1,
#  'TAAGCTAGATATCTTTTAAAAAATG': 1,
#  'TAAAATAAGATAATATCTAAAAATG': 16,
#  'AAGATAATATATATTTTAAAAAATG': 35,
#  'TACGATAATATATTTTTAAAAAATG': 4,
#  'AAATAAGAATAATATTTGAAAGATG': 1,
#  'TAAGATAATATATTTTAAAAAAATG': 53,
#  'ATAAGATAATATATGTTAAAAAATG': 11,
#  'GCTGCTGCTGCTGCTGCGGCGGCGG': 1,
#  'TCATAGAATGATCTGTTAAAAAATG': 1,
#  'GAATACAAGATAATATATAAAAATG': 1,
#  'TAAGATAATATACTTTAAAAAAATG': 2,
#  'AATAAGATGATGTCTTTAAAAAATG': 6,
#  'TGTATTTTTAAAAAATGCCACAGCG': 1,
#  'AAGTCGATGATCTATTAAAAAAATG': 1,
#  'AAGATAATATATTCAAGAAGATGAG': 1,
#  'AGATAATATATTTTTTTAAAAAATG': 3,
#  'GTAAAATAAGATAATATATTAAACG': 12,
#  'AATAGGATGATCTGTTGAAAAAATG': 1,
#  'AAATAAGATAATATCTTTAAAAATG': 2,
#  'TGACATAATATATTTTTAAAAAATG': 1,
#  'ATAATATATTTTTTAAAAAATGCCA': 1,
#  'AAAATAATATACATTTTAAAAAATG': 1,
#  'AAGATAATATATTTGACAAAAAATG': 1,
#  'TAAGATAATATATACCTAAAAAATG': 1,
#  'ATAAGATGATATTATTAAAAAAATG': 1,
#  'AATAAGATAATAGTTTTAAAAAATG': 1,
#  'TAGATGAAACCAGCACCTAAAAATG': 9,
#  'AATAAGATAATATATTCAAAAAATG': 3,
#  'AAGGATAGATATCTTTTAAAAAATG': 1,
#  'GTGGATGATATATTTTTAAAAAATG': 1,
#  'AGAATAAGATCATGTCTAAAAAATG': 1,
#  'ATAAGATAATATATTTTAAAGAATG': 26,
#  'GTAAATAAGATGATGTATAAAAATG': 1,
#  'AAGATAAATATATTTTAAAAAAATG': 1,
#  'AAAATAGATAATATATTAAAAAATG': 2,
#  'ATAAATTAATTATTTTTAAAAAATG': 1,
#  'AAAATAAGATAATCTGTACAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAAACG': 22,
#  'AATAAGATAATATATTTAAATAATG': 1,
#  'TAAGATGATGTCTGTTTTAAAAATG': 1,
#  'AAATAAGATAATATCCTTAAAAATG': 9,
#  'TGAAATAAGATGATGTCTAAAAATG': 1,
#  'AGTGAATAAATTGATGCTGGAACTG': 1,
#  'CAAATAAGATGATGTTGAAAAAATG': 1,
#  'TAAATAAGATGATATATTAAAAATG': 1,
#  'TGATACTGTGTTTTTTTAAAAAATG': 1,
#  'CAATAAGATAATATATTAAAAAATG': 1,
#  'GGAGTCAATATATTTTTAAAAAATG': 1,
#  'AATAAGATGATGTATTGAAAAAATG': 3,
#  'TGTTATCTGTTTAAAAATGCAGGCA': 1,
#  'AATAAGATAATATATTTAGAAAATG': 9,
#  'TAAGATAATATATTTTTAAAAAGTG': 23,
#  'TAAGATGATGTACTTTTAAAAAATG': 10,
#  'AAAATAAGATAATATGTAAAAAATG': 7,
#  'AAGATAGTGCTGTTTTGAAAAAATG': 1,
#  'ATGCAGTGTAGCTTTTTAAAAAATG': 1,
#  'AATGGTCAAGATGATCTATTGATTC': 1,
#  'ATAAGATGATCTATTTTAAAAAATG': 23,
#  'TAAGATAGTATATTTTTAAAAAATG': 42,
#  'AAGATAATATATTTATAGAGAAATG': 1,
#  'ATAAGATATATATTTTTAAAAAATG': 3,
#  'AAAGAATAATATATTTTAAAAAATG': 5,
#  'AAAGTAGATATATTTTTAAAAAATG': 1,
#  'ATATTTTTAAAAAATGCTAGGACGG': 1,
#  'TGAAGTCGATCATGCTTAAAAAATG': 1,
#  'AAATAAGATAATATCTGAAAAAGTG': 1,
#  'ATAAGAATATATTGCAGAAAAAATG': 1,
#  'TAAGATAATATATTTTCAAAAAATG': 15,
#  'AATAAGGTGGTTGTTGCAAAAAATG': 1,
#  'AGATAAGATGATCTGTTAAAAAATG': 1,
#  'GATAATATCTTAAAAATGCAGCAGG': 1,
#  'AATAAGATAACATATTTAAAAAATG': 6,
#  'AAAATAAGATGATGGCTAAAAAGTG': 1,
#  'TAAATGCAGTATTATTTAAAAAATG': 1,
#  'ATGTATTTTTTAAAAAATGCAGCGG': 1,
#  'TAAAATAAGATGATGTATAAAAATG': 7,
#  'ATGAATGATGTACTCTTAAAAAATG': 1,
#  'AAGATAATATGTATTTTTTGAATTC': 1,
#  'AGCATAGTATTTGAACTGCAGCAGG': 1,
#  'TAAGATAATATACCTTTAAAAAATG': 15,
#  'GTCGAGTGGATGATGTCTAAAAATG': 1,
#  'ATAAGATGATATTGTTGAAAAAATG': 4,
#  'AAGATCAGTGTGTTTTTAAAAAATG': 1,
#  'AAAATAAGATAATATCCTAAAAATG': 8,
#  'AAATAAGATAATATATTAAGAAATG': 8,
#  'TTAAAGAGCTGCTTCTGTCTCGGTC': 1,
#  'TAAATAAGATAATATTTAAAAAATG': 2,
#  'TAAGATAATATCCTTTTAAAAAATG': 1,
#  'TAATGTGATCTATCGTTAAAAAATG': 1,
#  'TAAGATAATATATTGTTAAAAAATG': 26,
#  'ATCAAGTGATCTGTTCCAAAAAATG': 1,
#  'ATAAGATAAAATATGTTAAAAAATG': 1,
#  'AATATATTTTTAAAAAATGCAGCGG': 23,
#  'TAAGATAATATATTTTGAAAAAATG': 10,
#  'TAAATAAGATAATATCCTTCGAGTA': 1,
#  'AAATAAGATAATATATTTAAAAATG': 49,
#  'AATAAGATAATATACTTTAAAGATC': 1,
#  'ATAAGATGATGTCCTTTAAAAAATG': 10,
#  'TAAGATAATATATCCAGAAAAAATG': 2,
#  'GAATGAGATGATCCTGTTTGAATTG': 1,
#  'AGATAATATATTTTTAAAAATGCGG': 1,
#  'TAAGATAATATATTGAGAAAAAATG': 3,
#  'AAATCAAATAATATCTTAAAAAATG': 1,
#  'TAAGATGGTCTTTTTTTAAAAAATG': 1,
#  'ACAAGATAATATATTTTAAAAAATG': 6,
#  'ATACGATTGATATTCTTAAAAAATG': 1,
#  'ATAAGATACTATATTTTAAAAAATG': 1,
#  'AAGTGAGTGGATCTCTTAAAAAATG': 1,
#  'AGAATAATGATGTCTTTAGAAAATG': 1,
#  'GTAAATAAGATAATATCTAAAAATG': 2,
#  'AATAAGATGATGTCTGTTAAAAATG': 1,
#  'TAGTAAATAAGATAATATATTGATG': 2,
#  'ATAAGATGATATCTTCGAAAAAATG': 1,
#  'ATAAGATATTATATTTTAAAAAATG': 2,
#  'CGAGTGATCTGTTGCCGAAAAAATG': 1,
#  'AAGATGACGTCTATGTTAAAAAATG': 1,
#  'AGATGGGATCTATTTTTAAAAAATG': 1,
#  'ATGAGATCATATATTTTAAAAAATG': 1,
#  'ATGAAGTAGATATCTTTAAAAAATG': 1,
#  'AACAAGATAATATATTTTAAAAATG': 1,
#  'ATATTTTTAAAAAATGCAGCAGCAT': 3,
#  'CTCCGATAGATGAAACCAGCACCTG': 19,
#  'TGGTGATCAGATGTCTTCAAAATTG': 1,
#  'ATGAACTGATGTATTTTAAAAAATG': 1,
#  'AATGAAGCATATATTTAAAAAAATG': 1,
#  'ATAAGATAATGTATCCAAAAAAATG': 1,
#  'TAAAATAAGATAATATATTAAATTT': 2,
#  'GTAAATGAGATAATATATTTAAACG': 1,
#  'AAATGATGTCCTTTTTTAAAAAATG': 1,
#  'AAAATGATGTATTTTTTAAAAAATG': 1,
#  'ATAAGATAATATATTTAAAAGAATG': 2,
#  'ACCAGCACCTATATTTTAAAAAATG': 1,
#  'AAGATAATATACCTTTTTAAAAATG': 1,
#  'AGATAATATATTTTTTAAAGAATCC': 1,
#  'AAATAAGATAATATATTCCGAGATG': 1,
#  'TGAGATAATATATCTTTAAAAAATG': 1,
#  'ATAAGATAATATATTATAAAAAATG': 1,
#  'TAAATAAGATGATGGTTTAAAAATG': 1,
#  'GCGCGCGCGCGCGCGCGCGCGGCGG': 1,
#  'AAAGATAATATATTTTTAAAAAATG': 8,
#  'TTAAAAAATGCAGCAGCAACAGGAG': 1,
#  'AAAATAAGATAATATATTAAAAATC': 3,
#  'AATAAGATAATATATTAAATTTGAG': 1,
#  'AAAATAAGATGATATTCTAAAAATG': 1,
#  'TATATTTTTAAAAAATGCAGGCACA': 1,
#  'ATAAGATAATATGTTTTTAAAAATG': 1,
#  'TAAGATAATATATTTAAAAAATGAG': 1,
#  'TGAGATAATATATTGAGAAAAAATG': 1,
#  'ATTTTAAAAAATGCAGCAGCGACTG': 1,
#  'TAATATATTTTAAAAAATGCAGCCG': 1,
#  'TAGATGATGATACTATTAAAAAATG': 1,
#  'AAAATAAGATAATATATTTAAAATG': 10,
#  'GTTAAAAAATAGGGCGCGCGCGGCG': 1,
#  'AATGCGGTGTCTTTTTTAAAAAATG': 1,
#  'AAAATAAGATAATATATTTTAATTA': 1,
#  'AAATAAGATAATTGTAGAAAAAATG': 1,
#  'TATCTGTTAAAAAATGCAGCAGGCG': 1,
#  'AAGATAATATCCTTTTTTAAAAATG': 1,
#  'TGAATAAGATGATCTGCTAAAAATG': 1,
#  'AAAATAAGATAATATATTGAAATCC': 1,
#  'TAATATACTTTAAAAAATGCAGCGG': 1,
#  'TAAGATGATCTACTCTTAAAAAATG': 1,
#  'AATTGTTATATATTTTTAAAAAATG': 4,
#  'AAGAATAACATATTTTTAAAAAATG': 2,
#  'ATATTTTTAAAAAACGCAGCAGTAG': 1,
#  'AAATGAGGTAATTGTTGAAAAAATG': 1,
#  'TGATTAGATGTATTTTTAAAAAATG': 1,
#  'TCAGATAATATATTTTTAAAAAATG': 11,
#  'GTCTTTTTAAAAAATGCAGCAGCCG': 1,
#  'ATAAGATAATATATTCTAAAAAATG': 17,
#  'ATAATTGTTATCTGTTTAAAAAATG': 1,
#  'GATGATCTGTTAAAAAATGCAGTAG': 1,
#  'TGCTGCTCTGCTGCTGCTGCTGCTG': 2,
#  'TAAATAAGATGATCTTTAAAAAATG': 4,
#  'GAAGATGATGATATTCTAAAAATAG': 1,
#  'AAAATAAGATGATGACTAAAAAGTG': 1,
#  'AAATAATAATATAGCTTAAAAAATG': 2,
#  'ATGATCTGATGATGTTTAAAAAATG': 1,
#  'AATAAGATAATATCTTTAAGAAATG': 2,
#  'ATAAGATGATCTGCTTGAAAAAATG': 2,
#  'AAGATAATATCTTTAAAAAATGCGG': 1,
#  'ATATTTTTAAAAAATGCAGCAGCGG': 30,
#  'AAATAAGATGATACTCTAAAAAATG': 1,
#  'AATAAGATAATATGTTCAAAAAATG': 1,
#  'AAATAAGATAATATATTTAAAGATG': 4,
#  'AAAATCAGGTGATTTGTAAAAAATG': 1,
#  'TAAGATAATATGTTTTTAAAAAATG': 28,
#  'ATAAGATGATGCTGTTTAAAAAATG': 17,
#  'TGAGGATAATATATTTTAAAAAATG': 1,
#  'GCGCGCGCGCGCGCGCGCGCGGGCG': 1,
#  'GATAATATATTTTTAAAAAATGCCG': 2,
#  'AAATAAGATAATATATTTTTCATTC': 1,
#  'ATAAGATAATATCTTTTAAAAAATG': 14,
#  'TAGATGAAACCAAAGCCTAAAAATG': 1,
#  'ATAAAATAATATCCTTTAAAAAATG': 2,
#  'TTGAGAATAATATATTTAAAAAATG': 1,
#  'GTAAAAATAAGATAATATCTGGATC': 1,
#  'AAGATGATCTGCTTTTTAAAAAATG': 1,
#  'TAAAATAAGATAATATTTAAAAATG': 2,
#  'ATAAATAAGATGATCCTTTAAAATG': 1,
#  'ATAAGGTAATATATTGCAAAAAATG': 1,
#  'TAAGATAAATATATTTTAAAAAATG': 5,
#  'ATAAGATAATATCTCTTAAAAAATG': 1,
#  'AAAATAAGATAATATCTTAAAAATG': 5,
#  'AAAATAAGATAATATATTAAAATTC': 1,
#  'TAATATATTTTAAAAAATGCGGCGG': 4,
#  'GTAAATAAGATGATGTATCGGTAGG': 1,
#  'GTAAATAAGATGATGCCTTGAATTC': 1,
#  'AAATAAATAATATATTTAAAAAATG': 2,
#  'ATAAGATGATGTGTCGAGTCCGGAG': 1,
#  'AATAAGATGATATCTTTTAAAAATG': 1,
#  'TAAGATAACATATTTTTAAAAAATG': 21,
#  'GTAAAATAAGATAATATTTGATGAG': 1,
#  'AAATAAAATAATATATTAAAGAATG': 1,
#  'TGAGATGATAATATATTAAAAAATG': 1,
#  'TAGTAAAATGAGTGTGTTAAAAATG': 1,
#  'AATAAGGTAATATATTTAAAAAATG': 8,
#  'AAAATAAGATGATATTTAAAAAATG': 2,
#  'TAAGATAATATATTTTAAAAAATAG': 1,
#  'TCTGTAAAAAATGTAAGAACAGCGG': 1,
#  'ATATAAGATGATCCTTTAAAAAATG': 1,
#  'AGTAAAATAAGATAATATAAAAATG': 6,
#  'AAATAAGATGATGTCTTGATAGGAG': 1,
#  'ATAAGACAATATATTTTAAAAAATG': 7,
#  'GATAATATATTATTTTTAAAAAATG': 8,
#  'ATTTTAAAAAATGCGGCAGCAGTAG': 1,
#  'ATAAGATGATATTTGTTAAAGAATG': 1,
#  'ATAGGATCATATATTTTAAAAAATG': 1,
#  'AAATAATAATATATTTCAAAAAGTG': 1,
#  'AAAATAAGATAATCTGTTAAAAATG': 14,
#  'ATAAGATGATATTCTTTAAAAAATG': 31,
#  'ATAAGATAATATATTTTTAAAAATA': 10,
#  'TAAGATAATATACTGTTTAAAAATC': 1,
#  'AAAATAAGATAATATATTTAAAATA': 2,
#  'TAAAATAATATATTTTTAAAAAATG': 32,
#  'ATAAGGATGATATCTTTAAAAAATG': 2,
#  'ATAAGATAATATATTTTTTAGAATG': 2,
#  'ATCAAGTGATGATGTCTAAAAAATG': 1,
#  'TAAAATAAGATAATATTAAAAAATG': 22,
#  'TAAGATAATATATTTTAAAAAGATG': 2,
#  'ATAAGATAGATATCTTTAAAAAATG': 6,
#  'ATAATATATTTAAAAAATGCAGCGG': 10,
#  'ATCAGATCAGATCTATTAAAAAATG': 1,
#  'AAAATAAGATAATGTGTTAAAAATG': 2,
#  'AGTAAATAGAATAATATATTAAATG': 1,
#  'GTAAGATGATATATTTTAAAAAATG': 1,
#  'TAAAATAAGATGATGTATCGAATTG': 1,
#  'TATTTTTTAAAAAATGCAGCAGCGG': 4,
#  'TAAGGTAATATATCTTTAAAAAATG': 4,
#  'GACATAATATATTTTTTAAAAAATG': 1,
#  'ATAATATATTTAAAAAATGCAGCAA': 2,
#  'GTAAAATAAGATAATATATTGATCC': 1,
#  'TGACATGGATCATGTGTTTAAAATA': 1,
#  'AAATAAGATAATATATTAGAAAATG': 1,
#  'GCTTGAATTGCAGCAGCGACGACGA': 1,
#  'AATAAGATAATATATTTTAAAAATC': 1,
#  'TCTAAAGTCTTAAGGTGTCATTGGT': 1,
#  'ATAAGATAATATCTGTTTAAAAATG': 1,
#  'AAACGATGATATTATTTAAAAAATG': 1,
#  'AATAAGATGATCTATTTAAAAAATG': 10,
#  'AGATAGAGTATATTTTTAAAAAATG': 1,
#  'AAGATAATATATTTTTAAAAAATGC': 5,
#  'AAATGATGATGCTGTTTAAAAAATG': 1,
#  'ATAAGATGATGTATTTTAAAAAATG': 17,
#  'ATAAGATAACATATTTTAAAAAATG': 3,
#  'AAGATAGTATATATTTTAAAAAATG': 1,
#  'GTAAATAGGATGATCTGTTGAATTG': 1,
#  'TAATATATTAAAAAATGCCGACGAG': 1,
#  'ATAGATGAAAACCAGCACCTAGTAG': 1,
#  'AAAATAAGATGATGTTGAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAAATC': 17,
#  'AAAATCACATGATATCTAAAAAATG': 1,
#  'ATAAGATAATATCTTTAAAAAAATG': 4,
#  'GATAATATATATTTTTTAAAAAATG': 5,
#  'AATAAATAATATATTTTAAAAAATG': 11,
#  'ACAGATAATATATTTTTAAAAAATG': 1,
#  'AAGATAATATATTACTGAAAAAATG': 1,
#  'TAAATAATGTATTTTTTAAAAAATG': 2,
#  'AAATAAGATGATGTCTTAAAAAATG': 10,
#  'AAATAAGATAATATATTTTAAAACG': 4,
#  'GATAATATATTTAAAAAATGCAGGA': 3,
#  'ATAAGATAATATATTAAAAATGCGT': 1,
#  'AAGATCATGTCCTTTACAAAAAATG': 1,
#  'AAGAATTGGGTGTTTTTAAAAAATG': 1,
#  'GAGTCAGTGATATACTTAAAAAATG': 1,
#  'AAGATAATATATTTTTTAAAAGATG': 5,
#  'AAAATAAGATGATGTCTACGAATTC': 1,
#  'ATAATATTGTTTAAAAAATGCAGGA': 1,
#  'AATAAGATAATACTGTTAAAAAATG': 6,
#  'AATAATATATTTTTAAAAAATGCGG': 2,
#  'AAAATAAGATAATCTGTAAAAAATG': 37,
#  'TAAATAATATATTTTTTAAAAAATG': 2,
#  'AAATAAGGTAATATATTAAAAAATG': 12,
#  'ATTAAATAATGTATTTCAATTGCGG': 1,
#  'GATCAATGCGCTGTTGCAGAAGATG': 1,
#  'AGATCAAACCAGCACCTAAAAAATG': 1,
#  'AAATCATATTACTTTTTAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAAATA': 10,
#  'ATAAGATAATATATTTAAAAAATGC': 3,
#  'AATAAGATGATGTCTTCAAGAATTG': 1,
#  'GTAAAATAAGATATTTTAAAAAATG': 1,
#  'TAAGATAATATATTGCGAAAAAATG': 2,
#  'TCTGCTGCTGCTGCTGCTGCTGCTG': 2,
#  'ATGTTATAGTAACCCTCTTATTCTC': 1,
#  'GTAAAATAAGATAATATATTAATTC': 2,
#  'TAAAATAAGATGATCTGTTTCGGTC': 1,
#  'TAAGATAATATATGCTTAAAAAATG': 3,
#  'TAGATAATATATTTTTAAGAAAATG': 1,
#  'ATAAGATAATATATTAAAAAAGTAG': 2,
#  'TAAAATGAGCTGATGCTTCTGAATG': 1,
#  'AAAATAATAATATATTTAAAAAATG': 14,
#  'AGAAATAAGATAATATATAAAAATG': 1,
#  'GAATAAAATAATATATTAAAAAATG': 1,
#  'TAAGATAATATATTGCTAAAAAATG': 3,
#  'ATAAGATGATATCTTTTAAAAAATG': 3,
#  'AGATGAAACCAGCACCTAAAAAATG': 11,
#  'AATAAGATCATGTACTTTAAAAATG': 1,
#  'AAATAAGATAATATATAAAAAAATG': 8,
#  'AATATATTTTTAAAAAATGCAGCTG': 7,
#  'TAAGATAATATACTGTTAAAAAATG': 3,
#  'ATAAATAATAATGCTTGAAAAAATG': 1,
#  'ATATTTTTAAAAAATCCAGCAGGAG': 1,
#  'AGTAAAATAAGATGATGTATCGTAG': 1,
#  'TAAATAAATAGGATGTACAAAAATG': 1,
#  'GTAAATAAGATGATGCTTAAAAATG': 1,
#  'AATAAGATAATATATTTAAAAAATC': 8,
#  'TAATATATTTTAAAAAATAGGCAGG': 1,
#  'AATAAGATAATATATTTTTGGATGC': 1,
#  'TAAAGTAATAATCTGTTAAAAAATG': 1,
#  'CCTGATAATATATTTTTAAAAAATG': 4,
#  'GCTGCTGCTGCTGCTGCTGCTGTAG': 1,
#  'ATATTTAAAAAATGCAGCAGCACGA': 1,
#  'AAAACAAGAAATACATTAAAAAATG': 1,
#  'TAATGCAAGTATTTTTTAAAAAATG': 1,
#  'AAGTTAATATATTTAAAAAGAAATC': 1,
#  'AAGATGATCTATTTTTGAAAAAATG': 3,
#  'GAATTAAGATAATATCTAAAAAATG': 1,
#  'AAATAAGATAATATACTAAAAAATG': 18,
#  'AAAATAAGATAATATCTTCAAGATG': 1,
#  'ATGAAACCAGCACCTTGAAAAAATG': 2,
#  'AATAAGATAATATATCCAAAAAATG': 4,
#  'AATAGGATAATATATTTAAAAAATG': 3,
#  'ATACTTTATTTTACTTATAAAAATG': 1,
#  'TAAAATAAGATAATATATAAAAATC': 2,
#  'TAAATGCAGTATCTTTTAAAAAATG': 2,
#  'CAAGATAATATATTTTTAAAAAGTG': 1,
#  'AAAATATGATGATGTTTAAAAAATG': 1,
#  'GTAAAATAAATATGCTTAAAAAATG': 1,
#  'TAAATAAGATAATATATAAAAAATG': 9,
#  'AATACAATAATATATTTAAAAAATG': 2,
#  'ATAAGGTAATATATTTTAAAAAATG': 10,
#  'GTAAATAAGATGATGTATTGAATTC': 1,
#  'AAATAATAATATATTTTTAAAAATG': 3,
#  'TTGATGATCATGTGTTTAAAAAATG': 1,
#  'TAAGATAATACATTTTTAAAAAATG': 17,
#  'AATAAGATAATATATTGAAAAAATG': 6,
#  'ATAAGATAATATGTTTTAAAAAATG': 5,
#  'TAAATAAGATGATGTATTAAAAATG': 1,
#  'AAATAAGATAATCTGCTAAAAAATG': 4,
#  'ATAAGATAATACTTTTTAAAAAATG': 2,
#  'AAAATGAAGCATTCTTTAAAAAATG': 1,
#  'ATAAGATAATATCCTTTAAAAAGTG': 2,
#  'AAAATAAGATGATCTGTAAAAAATG': 9,
#  'TGGAGTGATGGATATTCTTGAATAG': 1,
#  'GAGAATAATATATTTTTAAAAAATG': 1,
#  'CCAGATAGATGAAACCAGCACCTAG': 1,
#  'TAAGATAATACTTTTAGAAAAAATG': 1,
#  'ATCAAGTCGATGATGTGTTCAAACG': 1,
#  'ATAATATATTTTTAAAAAATCCGAG': 3,
#  'AATGAGGTCGTATATTGAAAAAATG': 1,
#  'AATAAGAAAATATATTTTAAAAATG': 1,
#  'AGATAATATACTGTTTGAAAAAATG': 1,
#  'AAGATAATATATTTTTCAAAAAATG': 12,
#  'TCATGATGATATATTTGAAAAAATG': 1,
#  'ATATACATTTTAAAAAATGCAGCGG': 1,
#  'TAATATATTCCAAAAAATGCAGCGG': 1,
#  'ACTACTACTACTGCTGCTGCTGCTG': 2,
#  'TATATTGTTAAAAAATGCAGGCAGG': 1,
#  'AGATAATATCTATTTTTAAAAAATG': 5,
#  'AAATAAGATGATGTCTGAAAAAATG': 3,
#  'TCAATGATGATATCTTTAAAAAATG': 1,
#  'AATAAGATAATATATTTAAAAGATG': 6,
#  'ATCATAATAAGATTGTTAAAAAATG': 1,
#  'AATCAAGTAGTATCTTTAAAAAATG': 2,
#  'AATAATGTGTTTTTTTTAAAAAATG': 1,
#  'AAGATAATATAATTTTTAAAAAATG': 10,
#  'AATAAGATGACGTCCTTAAAAAATG': 1,
#  'TTAGATGATGTCCTTTAAAAAAATG': 1,
#  'ATAAGATAATATATTTTAAAAGATG': 17,
#  'TAATATATTTTTAAAAAAATCCGAG': 2,
#  'TGAGATGATGTATTTTTAAAAAATG': 2,
#  'AAATAAGATGGTGTATTTTTGATTC': 1,
#  'AGATAATATATTTTTAGAAAAAATG': 10,
#  'AATAGATAATATATTTTTAAAAATG': 1,
#  'TAAGATAGATATAGTTTAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAACTG': 2,
#  'TAAAATGCGATATTATTAAAAAATG': 1,
#  'GTAAAATAGAGTGATCTATTAAATG': 1,
#  'ATAAGATGATATATTTTAAAAAATG': 7,
#  'AAATGCAGTATCTTTTTAAAAAATG': 1,
#  'CAAAATAATAATATATTAAAAAATG': 1,
#  'TAAAATAAGATGATCTATTGAATTC': 2,
#  'TAATATATTTTAAAAAATACAGCAA': 1,
#  'ATGAGGATGATATTATTAAAAAATG': 1,
#  'ATGGGATCTTATTTTTTAAAAAATG': 1,
#  'AATAAGATGATATTTTTAAAAAATG': 4,
#  'AAATAATAAATACCTTTAAAAAATG': 1,
#  'TGGATGACGATATTTAGAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAATGC': 1,
#  'ATAATATCGTTTTTTTTAAAAAATG': 1,
#  'GTAAAATCGAGTGATCTTCAAAATG': 1,
#  'AATAAGATAATATATTTAAAAAATA': 2,
#  'CAAGATGATGCATTTTTAAAAAATG': 1,
#  'AATGAGATAATATCTTTAAAAAATG': 1,
#  'TAGATAATATATTTTAGAAAAAATG': 1,
#  'GATAATATCTTAAAAAATGGGGCGG': 1,
#  'ATTCAGTGATCTATTTAAAAAAATG': 1,
#  'GCACATGAGGCCCCACGTGGACAGG': 1,
#  'ATAAGATAATACTGTTGAAAAAATG': 2,
#  'AATAATATATATTTTTTAAAAAATG': 1,
#  'TAAAATAAGATAATATATCGAGTAC': 1,
#  'GATAATATACACTTTTTAAAAAATG': 1,
#  'TAAGATAATATATCCTTAAAAAATG': 3,
#  'ATAAAGTAGTATCCTTTAAAAAATG': 1,
#  'AAAATAAGATAATATATTTGAATTG': 1,
#  'TAGATGATGTCTTTTTTAAAAAATG': 1,
#  'AGTAAATAAGATAATATATAAAATG': 2,
#  'AATAAGATGATATTATTAAAAAATG': 7,
#  'AAATAAGATAATATGTTAAAAAATG': 13,
#  'GGATGATTGTCTTTTTTAAAAAATG': 1,
#  'AGATGATGTGCTTTTTTAAAAAATG': 2,
#  'AGATAATATATTTTGAGAAAAAATG': 4,
#  'AGATAATATATTTTTAGAAAAATTG': 1,
#  'TCAATGATGTCTTTTTTAAAAAATG': 1,
#  'TTCTGGTTTCCCGAGGAAGTGTGGC': 1,
#  'TAATATCTAAAAAATGCAGCAGTAG': 1,
#  'TATAATTGTTATCTTTTAAAAAATG': 2,
#  'GATCAATGATATTCTTTAAAAAATG': 1,
#  'AAAATACGATGATATCTAAAAAATG': 1,
#  'ATAAGATGATCTTGTTGAAAAAATG': 1,
#  'AAATAAGATAATATATTGATAGGAG': 2,
#  'TATATTTTAAAAAATGCAGCAGCGG': 10,
#  'TAATATATTTAAAATGCAGCAGCGG': 1,
#  'TTTAAAAATCCGGGCGGCGGCGCGG': 1,
#  'AGATAATATCTTGAATTCCGGGGCG': 1,
#  'TAAGTAATATTATTTTTAAAAAATG': 1,
#  'TGAGATTAAATATGTTGAAAAAATG': 1,
#  'AAAATAAGATAATATACTAAAGTTG': 1,
#  'AAATAAGATGATCTGTAAAAAAATG': 1,
#  'ATAAAATATATATTTTTAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAATTG': 3,
#  'ATAAGATAATATATTTTAAAAAACG': 16,
#  'AAAATAAGATAATATATTCAAAATG': 2,
#  'TAAGATAATATCTATTTAAAAAATG': 2,
#  'TAGAATAAGATCATGCTAAAAAATG': 1,
#  'GTAAAATAATGATGTTTAAAAAATG': 1,
#  'TAATATATTTTTAAAAAATGCCGAG': 1,
#  'AGATAATATATTTTAAAAAATGTAG': 5,
#  'GTAGATAATATATTTTTAAAAAATG': 8,
#  'AAGATGATGTCTTTTTTAAAAAATG': 4,
#  'ATAAGATAATATACTTTAGGAATTG': 1,
#  'AAGATATAATATATTTTAAAAAATG': 3,
#  'TAAATAATGTCTTTTTTAAAAAATG': 1,
#  'AAGATAATATCTATTTTAAAAAATG': 2,
#  'TAAGATAATATATTTATAAAAAACG': 1,
#  'TAAGGTAATATATTTTCAAAAAATG': 1,
#  'TCGGATAATATATTTTTAAAAAATG': 1,
#  'AAATAAGATAATATATTTTAAAATA': 1,
#  'AAGATAATATATTTCTTAAAAAATG': 11,
#  'TAAAATAAGATAATCTGTAAAAATG': 5,
#  'AAAATAAGATCATGTCTAAAAAATG': 5,
#  'AGTAAATAAGATAATATATTAGATG': 1,
#  'AAATAAGATAATCTGTAAAAAAATG': 2,
#  'AGATAATATATAATTTTAAAAAATG': 1,
#  'ATATATTTAAAAAATGCAGCAGCGA': 2,
#  'GATGTTATGGTACTATCTTAAAATA': 1,
#  'AATAAGAATAATATTTTAAAAAATG': 1,
#  'AAATGAGGTAGCTGTTTAAAAAATG': 1,
#  'AAGATAATATATTTTAGAAAAAATG': 7,
#  'ATATATTTAAAAAATGCAGCAGCTG': 2,
#  'TAAGATAATATATTTTTAAAATATG': 1,
#  'AAATGCTTGACAGCATAACACGTAG': 1,
#  'TAAAATAAGATAATATTATTAATCC': 1,
#  'TAAAAATAGATAATATATTAAAATC': 1,
#  'GATATCTTAAAAAATGCAGCAGTAG': 1,
#  'GATCATGTATTTTTAAAAATACGAG': 1,
#  'GATAAGATAATATACTTAAAAAATG': 2,
#  'ATAATAATATATACTTTAAAAAATG': 1,
#  'AAAATAATATAATCTGTAAAAAATG': 1,
#  'GTATTTTTTAAAAAATGCAGCAGGC': 1,
#  'AGAATAAGATAATATATAAAAAATG': 2,
#  'ATGAGATGATATTGTTGAAAAAATG': 1,
#  'GATCGTAGATGATGTTGTTGAATTG': 1,
#  'AAATCAAGAATATATTTAAAAAATG': 1,
#  'TCAATGCAGTGTAGCTTAAAAAATG': 1,
#  'AAGATAATATATTTTAAAGAAGTAG': 3,
#  'GATCTATTAAAAAATGCAGCAGCGG': 1,
#  'AAGATAATATGTTTTTTAAAAAATG': 1,
#  'ATAGATAATATATTTTTAAAAAATG': 16,
#  'ATCAAGATGATGTCTTTAAAAAATG': 1,
#  'GTAAAATAAAATAATATATTAAACG': 1,
#  'GCGCGCGCGCGCGCGGCGGCAGCGG': 1,
#  'GATAAGGTAATATATTTAAAAAATG': 1,
#  'CGCGGGCGCGGGCGCGGGCGCGGCG': 1,
#  'ATTGAATATCTATTAAAAAATGCGG': 1,
#  'TTTTTTAAAAAATGCAGCAGCGAGA': 1,
#  'AATCAAGTAGTATTGTTAAAAAATG': 1,
#  'AGAATAAGATAATATATTAAAAATG': 1,
#  'AATAAGATAATATCCTGAAAAAATG': 2,
#  'AGAATAATATATTTTCTAAAAAATG': 1,
#  'AAGATAATATATTAAAAAATCCGAG': 1,
#  'ATAAGATAATATATTTAAACAGTAG': 1,
#  'AATAAATAAGATAATATATTGATTG': 1,
#  'ATATAGATAATATATTTAAAAAATG': 1,
#  'GATAATATATTTTAAAAAAATGCGG': 1,
#  'ATCATAATATATTTTTTAAAAAATG': 1,
#  'ATATCTAAAGAATTGCAGCAGCAAG': 1,
#  'AGATGATGTATTTTTTGAAAAAATG': 1,
#  'GATAGATATCACTTTTTAAAAAATG': 1,
#  'ATAAGATAATATATTTTTGGATTTC': 1,
#  'AGATAATATCCTTAAAAAATCCGAG': 1,
#  'TTTAAAAAATGCAGCAGCGGCGGGG': 1,
#  'ATAATGTGTCAAAATGCAGCAGCGG': 1,
#  'GTTACTGCTGCTGCCGCAGCAGTAA': 1,
#  'TAAGATAATATATTTTTTAAAAATC': 3,
#  'AAAATAAGATGATGTATTAAAAATG': 5,
#  'AAAAAATGCAGCAGCATAAGCGTAG': 1,
#  'ATAAGATAATATATTCCGAAAAATC': 1,
#  'TAAAATTAGATAATATATTAAAATC': 1,
#  'AATAAGATGATCTGTTTAAAGAATG': 1,
#  'ATAAGATGATGTACTTGAAAAAATG': 1,
#  'AATAAGATAATACGTTTAAAAAATG': 1,
#  'TAAAATAAGATAATATATTAAATTG': 11,
#  'ATAAATAATATATTTTTAAAAAATG': 8,
#  'TAAGATGATCTGTTCCGAAAAAATG': 1,
#  'GTAAAATAAGATAATATAAAAAATG': 5,
#  'AGATAATATATTTAAAGAATGCAGG': 1,
#  'AATATGATGATGTGTTTAAAAAATG': 1,
#  'CAAGATAATATACTTTTAAAAAATG': 1,
#  'TAGAGTAGAATATATTTAAAGAATG': 1,
#  'TAAGATGATGTATCTTTAAAAAATG': 1,
#  'TGTCCTTTAAAAAATGCAGCAGCCG': 1,
#  'GCTGCTGTACATTCTTAAAAATATG': 1,
#  'AAATAAGATAATACATTAAAAAATG': 3,
#  'TGCGATTAGATATTATTAAAAAATG': 1,
#  'TAGATGATGTACCTTTTAAAAGATG': 1,
#  'AAGATAATATATATTTTAAAAAACG': 1,
#  'AATAAGATAATATATTTAAAAAGTG': 7,
#  'AATCGGATTGATCTGTTAAAAAATG': 1,
#  'AAGATAATGTTCTGTTTAAAAAATG': 1,
#  'ATAAGATAATATACTTTTAAAAATC': 1,
#  'AATCCAGTGTCCTTTTTAAAAAATG': 1,
#  'TAAATATAAATATATTTAAAAAATG': 1,
#  'AGAATGAGATGATGTATTAAAAATG': 1,
#  'TAATATATTTTTAAAAAATGCAGGA': 8,
#  'AAGTGGATGGGATGTTTGAAAAATG': 1,
#  'TAAAATAAGATGATGTCTAAAAATG': 17,
#  'AATATAGATAATTTATTAAAAAATG': 1,
#  'TAAGATAATATATTTTTAAAAATCC': 2,
#  'TAAGGATGAATATTTTTAAAAAATG': 1,
#  'AAGATAATATATTTAAAGATCCGGG': 1,
#  'ATCAAGTGATCTATTTTAAAAAATG': 4,
#  'GAATAAAAATAATATTTAAAAAATG': 1,
#  'ATAAGATGATACTGTTTAAAAAACG': 1,
#  'ATAATATATTATTAAAAAATGCAGG': 1,
#  'AAATAAGATAATATATCGAATGCGG': 1,
#  'AAAAATGCAGCGGCAGCAGCGGCGG': 1,
#  'GATAATGTATTTTTAAAAAATGCGG': 1,
#  'TAAGATAATATTTTTTTAAAAAATG': 5,
#  'TTGATGGTATATATTTTAAAAAATG': 1,
#  'TAGTAAAATAAGTGTTTAAAAAATG': 1,
#  'TAAGATAATATCATTTTAAAAAATG': 1,
#  'AAGATAATATTATTTTTAAAAAATG': 3,
#  'ATAGAATAATATATCTAAAAAAATG': 1,
#  'ATAAGTTAATATATTTTAAAAAATG': 5,
#  'AAGATAATAATATTTTTAAAAAATG': 1,
#  'TTTTTAAAAAATGCAGCAGCGGCGG': 7,
#  'AATAAAGTAGTATCTTTAAAAAATG': 2,
#  'TGAAGATGATGATCTGTTGCGACTG': 1,
#  'TAATATATTTTTAAAAAATGCAAGG': 2,
#  'TACGATGATCTATTTTTAAAAAATG': 1,
#  'AGTAAAATGAGATGATCTAAAAATG': 1,
#  'ATAATATCCTGTTCTCCAAAAAATG': 1,
#  'TAAGTAGATAATATATTAAAAAATG': 1,
#  'GATGATGATGTATTTTTAAAAGATG': 1,
#  'TAAAATAAGATAATATATTGAACTG': 1,
#  'ATAAGATAATATAACTTAAAAAATG': 3,
#  'AAATATAATAATATATTAAAAAATG': 3,
#  'TAAGGTGATTGTCTTTTAAAAAATG': 1,
#  'GATATGATATTATTTTTAAAAAATG': 1,
#  'AAATAAGATGATGTTCTAAAAAATG': 4,
#  'ATAAGAATAATATCTTTAAAAAATG': 5,
#  'TAAGATGATATTATTTTAAAAAATG': 4,
#  'AGATAATATATTTTTAAAAATACGG': 1,
#  'ACTATTACTACTACTACTACTACTG': 1,
#  'AAATAAAATAATATATTAAAAAATG': 6,
#  'TCCAGTAATCTATTTTTAAAAAATG': 1,
#  'TAAAATAAGATGATGTATCGAACTG': 1,
#  'AAAATAAGATGATGTCTTAAAAATG': 1,
#  'AGAATGATGATATTATTAAAAAATG': 1,
#  'AAATAATAATATACTTTAAAAAATG': 4,
#  'AAGATAATATATAGTTTAAAAAATG': 5,
#  'AAGTAAATAAGATAATATATTGATG': 1,
#  'AATAAGATGATATATTTAAAAAATG': 7,
#  'GCGGCGGGCGCGGCGCGCGCGCGCG': 1,
#  'AATAAGATAATATTTTGAAAAAATG': 1,
#  'AAGATGATGATATTCTTAAAAAATG': 3,
#  'TTAAAAAATGCAGCAGCGGCGAGAA': 1,
#  'TACAATAATATCTTTTCAAAAAATG': 1,
#  'AAAATAGAATTAATGTTTAAAAATG': 1,
#  'AAGATAATATACATTTTAAAAAATG': 2,
#  'ATGATGCTGTTTAAAAATGCGGCGG': 1,
#  'AAATAAGATAATGTGTTAAAAAATG': 2,
#  'AATAAGATAATATATTTTAAAAATA': 6,
#  'AAGATAGATATATTTTTAAAAAATG': 4,
#  'AGGTAATATATATTTTTAAAAAATG': 1,
#  'TAAGATGATATTGTGTTAAAAAATG': 1,
#  'AAATGAGATAATATATTTAAAAATG': 1,
#  'AAATAAGATAATATTTTTAAAAATG': 2,
#  'AAGATAATATACTTTTAAAAAAATG': 2,
#  'TAAGATAATGTGTTTAAAGAAAATA': 1,
#  'TAAAGTGTGTTTTTTTTAAAAAATG': 1,
#  'TAAGATAATATACATTTAAAAAACG': 1,
#  'TCAAGATAATATATTTTAAAAAATG': 6,
#  'GTGATTGTACATTTTTTAAAAAATG': 1,
#  'GTAAATAAAGATGATGTATTGAATG': 1,
#  'AATAAGATGATAATTTTAAAAAATG': 1,
#  'TTAAAAAATGCGGCAGCAGCGGCGG': 2,
#  'ATAAAATAATATCTTTTAAAAAATG': 2,
#  'AATAAGATAATACTGTTAAAAAACG': 1,
#  'AATAAGATAATACATTTAAAAAATG': 7,
#  'CTGCAGCAGGAGCGGCGCGCGCGCG': 1,
#  'AAATAGGATCGTGTCTTAAAAAATG': 1,
#  'TAAAATAAGATAATATATCGAATTC': 1,
#  'GATAATATATTAAAAAATGCAGCGG': 5,
#  'TAAATCTGGTGATATTATTAAGATG': 1,
#  'ATAAGATGATGTCTTTTAAAAAATG': 2,
#  'AGGATAGATATCTGTTTAAAAAATG': 1,
#  'CACCTGATAATATATTTTAAAAATG': 1,
#  'AAAATAAGATAATATATAAAGAATG': 1,
#  'AAATAAGATCATGTGTTAAAAAATG': 2,
#  'AGATAATATATTTTTGAAAAAAATG': 3,
#  'TGAACATAATATATTTTTAAAAATG': 1,
#  'AGATAATATATTTTTTAAAAAAATG': 7,
#  'ATAAGATAATATATTTTAAAAATAC': 1,
#  'TATATTATCTTATTTTAAAAAAATG': 1,
#  'AAATAAGATGATGTTTGAAAAAATG': 1,
#  'CAAATAAGATAATATATTACAATTG': 1,
#  'AAAAAATGCAGCAGCGGCGGGGCGG': 1,
#  'CTGTGTGCTGCTGCTGCTGCTGCTG': 1,
#  'TAGATATTGATTTTTTAAAAAAATG': 1,
#  'GTAAAATAAGATGATCTAAAAAATG': 5,
#  'ATAATATATAAAAATACAGCAGCGG': 1,
#  'GAGACCAGATATCTTTTAAAAAATG': 1,
#  'ATATTTAAAAAATGCAGCGGCGGCA': 1,
#  'TAAAATAAGATAATATATTTAAATG': 5,
#  'ATAAGATTATATATTTTAAAAAATG': 2,
#  'AGGATACAGATATCTTTAAAAAATG': 1,
#  'TAAGATAATATATTTTTAATAAATG': 4,
#  'TCGTCGATGATGATCTGTTGAACTC': 1,
#  'TAAGATAATATATTTTTAAAAGATG': 26,
#  'GCTGCTGCTGCTGCTGCTGCAGGAG': 1,
#  'TTAAAAAATGCAGCGGCGGCGGCGG': 3,
#  'ATAAGATAATATATTTTGAAAAATG': 7,
#  'TAAAATAAGATGATCTGTAAAGATG': 1,
#  'TAAATAAGATAATATATTCAAAACA': 1,
#  'ATATGATGATATTCTTTAAAAAATG': 2,
#  'GATAATATGTTTTTAAAAAATGGAG': 1,
#  'GTGATTGAGTAATATACAAAAAATG': 1,
#  'AATAAGAATAATCTGTTAAAAAATG': 1,
#  'AAGTAAGATAATATATTAAAAAATG': 7,
#  'ATAAGGATCATATATTTAAAAAATG': 1,
#  'GAAGATAATATATTTTTAAAAAATG': 6,
#  'TTAGATAATATGTTTTTAAAAAATG': 1,
#  'TAAAGATAAATATCTTTAAAAAATG': 1,
#  'AAAATAAGATAATATATTAAATATG': 2,
#  'AAATAGAGTGATCTGTTAAAAAATG': 2,
#  'GAGATTGAGTGTCCTTTAAAAAATG': 1,
#  'AATATATTTTTAAAAAATGCAGGAG': 13,
#  'AATAAGATAACATGTTTAAAAAATG': 2,
#  'AGATAATATATTTTTTGAAAAAATG': 3,
#  'AAGATGATGTCGTTTTTAAAAAATG': 1,
#  'AATAAGATGATATCTTGAAAAAATG': 1,
#  'TAAGATGATGTCCTTTTAAAAAATG': 2,
#  'GGAGTCGATAATATTGTTAAAAATG': 1,
#  'AATAAGATAATATATTTTTAAAATG': 7,
#  'ATATTTTTAAAAAATGCAGCAGCAC': 1,
#  'ATAGATAATTTATTTTTAAAAAATG': 1,
#  'AAATAAAGTGAGTGTCTAAAAAATG': 1,
#  'GTAAAACAAGATAATGTAAAAAATG': 1,
#  'AATAATAATATATTTTTAAAAAATG': 67,
#  'TAAGATAATATATTTTAGAAAAATC': 1,
#  'TAAGATAATACCTTTTTAAAAAATG': 1,
#  'ATACTTCCTCATACTGCTTATCTAG': 1,
#  'ATATTCAGAAAAAATGCAGCAGCGG': 1,
#  'TAAAATGCAGTCTGTTGAAAAAATG': 1,
#  'TTTAAAAATATATCTTTAAAAAATG': 1,
#  'TAATATCTGTTAAAAAATGCAGCAA': 1,
#  'AATAAGATAATCTGTAGAAAAAATG': 3,
#  'AGATAAATATATTTTTTAAAAAATG': 3,
#  'TAAGATAATATAAATTTAAAAAATG': 1,
#  'AGATAGATAATATATTTAAAAAATG': 2,
#  'TTAAAAAATGCGGCGGCGGCGGCGG': 2,
#  'TAAAATAAGATAATATATAGAATTC': 1,
#  'AGAATAAGATAATATTTAAAAAATG': 2,
#  'AAGATGATGTATCTCTTAAAAAATG': 1,
#  'TAAAAAATGCAGCAGGGGCGGCAGG': 1,
#  'AAATAGGATGATCCTTTAAAAAATG': 2,
#  'TAAAATAAGATCATGTAGAAGAATG': 1,
#  'AATATACTTTTAAAAAATACAGGAG': 1,
#  'AATAAGATGATGTATTTAAAAAATG': 5,
#  'AAAATAAGATGATGTACTTGAATTG': 1,
#  'TGATATTATTGAATTGCGGCGGCGG': 1,
#  'GATGATGCAGTATCTTTAAAAAATG': 2,
#  'CGATAGATCGAAACCAGCGCCTGAG': 1,
#  'AAATAAGATGATGTATTAAAAAATG': 16,
#  'GCGGCGGCGGCGGCGGCGGCGGCGG': 63,
#  'AAGATAATATTATCTTTAAAAAATG': 1,
#  'AATAAGATGATGTGTTGAAAAAATG': 2,
#  'GCGAAGTGATGATTGTTTAAAAATG': 1,
#  'TAAGATCATATATTTTTAAAAAATG': 3,
#  'AAAATGATGGGTGGCCGAAAAAATG': 1,
#  'AAGAAAAATATATTTTTAAAAAATG': 2,
#  'AAAATAAGATAATCTTAAAAAATAC': 1,
#  'TAAGATAATATCTTTTTAAAAAATG': 3,
#  'ATAAGATTAAATATGTTTAAAAATA': 1,
#  'CAGACTAATATATTTTTAAAAAATG': 1,
#  'TCAATGAGATGATGTCTAAAAAATG': 2,
#  ...}

# %%
# If you want to get all keys with the maximum value
max_keys = [key for key, value in fwd_prefixes.items() if value == max(fwd_prefixes.values())]
print("Keys with maximum value:", max_keys)
# Out:
# Keys with maximum value: ['CTTCATGTTAGAAAACCTGGCTTTA']

# %%
# If you want to get all keys with the maximum value
max_keys = [key for key, value in rev_prefixes.items() if value == max(rev_prefixes.values())]
print("Keys with maximum value:", max_keys)
# Out:
# Keys with maximum value: ['TAAGATAATATATTTTTAAAAAATG']

# %%
rev_comp('CTTCATGTTAGAAAACCTGGCTTTA', COMPLEMENT)
# Out:
# 'TAAAGCCAGGTTTTCTAACATGAAG'
